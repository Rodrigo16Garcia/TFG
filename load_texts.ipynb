# %%
import chromadb
import uuid
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# %%
embedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size= 2000, chunk_overlap=100)

chunks = PyPDFLoader(r"C:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\BOCYL-D-17052024-2 2024.pdf").load_and_split(splitter)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size= 2000, chunk_overlap=100)

chunks = PyPDFLoader(r"C:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\decreto de infantil 30 de octubre 29 DE SEPTIEMBRE.pdf").load_and_split(splitter)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size= 2000, chunk_overlap=100)

chunks = PyPDFLoader(r"C:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\Decreto primaria octubre 29 SEP 2022.pdf").load_and_split(splitter)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size= 2000, chunk_overlap=100)

chunks = PyPDFLoader(r"C:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\Decreto secundaria octubre.pdf").load_and_split(splitter)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size= 2000, chunk_overlap=100)

chunks2 = PyPDFLoader(r"C:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\Franz_Kafka_The_Metamorphosis.pdf").load_and_split(splitter)

# %%
len(chunks)
# Out:
# 111

# %%
embedding_model.embed_documents(chunks[1].page_content)
# Out:
# [[-0.028164828196167946,
#   -0.024786600843071938,
#   -0.09065123647451401,
#   0.04615801200270653,
#   -0.03429999202489853,
#   -0.071649469435215,
#   0.09874621033668518,
#   0.05291057750582695,
#   -0.00465413648635149,
#   -0.05686274915933609,
#   -0.027819231152534485,
#   -0.1366635411977768,
#   0.004582188092172146,
#   -0.03427981957793236,
#   -0.013689618557691574,
#   0.10034561157226562,
#   -0.11418335884809494,
#   -0.030056005343794823,
#   -0.029333211481571198,
#   -0.0614357516169548,
#   0.022478707134723663,
#   -0.02064652368426323,
#   0.05151912942528725,
#   -0.009631836786866188,
#   -0.0760757103562355,
#   0.007215217221528292,
#   -0.018743783235549927,
#   0.04271320998668671,
#   -0.007576627191156149,
#   -0.10381785035133362,
#   0.01624867506325245,
#   -0.016131378710269928,
#   -0.0033528669737279415,
#   -0.05422106012701988,
#   0.02693161368370056,
#   -0.09003181010484695,
#   0.0178265031427145,
#   -0.034206610172986984,
# ...

# %%
# from langchain_core.documents import Document

# chunks = [Document(page_content="Hola", metadata={"page": 3333})]

# %%
client = chromadb.HttpClient("localhost", 7888)

# %%
collection = client.get_or_create_collection("prueba_kafka")
collection.add(ids=[str(uuid.uuid4()) for _ in range(len(chunks))], documents=[doc.page_content for doc in chunks], metadatas=[doc.metadata for doc in chunks])

# %%
collection.get()["documents"], len(collection.get()["documents"])
# Out:
# (['También tendrán acceso a las pruebas que se les apliquen a sus hijos o tutelados, \nen la forma que se determine por los centros.\n2. Al principio de cada curso, el profesorado informará al alumnado sobre las \ncompetencias específicas, los criterios de evaluación, los contenidos, los procedimientos e instrumentos de evaluación y los criterios de calificación de las respectivas áreas y, en su caso, ámbitos. Asimismo, quienes ejerzan la tutoría de los grupos les informarán sobre \nlos criterios de promoción.\n3. Los centros educativos trasladarán esta información, así como las medidas que se \nadopten para la atención individualizada del alumnado, a los padres, madres o personas \nque ejerzan la tutela legal.\n4. Tras las sesiones de seguimiento y de evaluación final, quien ejerza la tutoría del \ngrupo facilitará a los padres, madres o personas que ejerzan la tutela legal del alumnado un boletín individualizado, que incorporará, al menos, las calificaciones obtenidas en cada área 
# ...

# %% [markdown]
# vectorstore = Chroma.from_documents([chunks], embedding = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2"))

# %%
collection = Chroma(collection_name="prueba_kafka", client=client,  embedding_function=SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2"), persist_directory=r"C:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\desarrollo\prueba")
# Out:
# c:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# c:\Users\Usuario\Desktop\Universidad_23_24\TFG\EL_NUEVO\.venv\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# ...

# %%
collection.add_documents(chunks2[0:50])
# Out:
# ['f4d22caa-bbb2-4669-98a3-c811eb77471e',
#  'c9d071cf-4fbb-41f9-84a9-d211952873fa',
#  '3b466448-9fe1-4ca6-8486-c1529cfb51f4',
#  'e851add0-67ea-4385-86de-3d0506c62826',
#  'e6e8b971-0c1b-48cf-9d3e-ca1953964dd5',
#  '53ea9f72-a190-4e60-97a8-d57ebefbfe60',
#  '053d9339-e241-4ac8-a53a-f443cda5198d',
#  '435b4785-2646-4dfc-a595-e8e622cde022',
#  'dde68a20-2430-4ccc-bd42-fe821e553ecc',
#  'ae8ba224-26f1-47fb-bbfd-4159b37f2ed5',
#  '2f8628ee-35a5-4750-9800-89e3f7782af3',
#  'a5aa99d5-d0d3-4a3c-bb71-9b02c808104f',
#  'cb59832b-8c15-4287-bf24-1aa43dcbdf16',
#  'e40b61d0-33e7-418a-af81-107f2d317ecf',
#  'e5a1f899-a0f2-49af-a16b-ed83bd5e81fe',
#  '1a754f2d-1664-45fb-a55d-01fa44421261',
#  'db739dbd-3c41-487f-a933-8ee1bf4d4414',
#  '01105af1-8af9-498a-9979-d234adf85a1b',
#  '17e58d8b-e5bc-46c1-82e3-e821159fce5f',
#  '62b31824-b5ec-43e8-a0af-cf7bd8f5c8dd',
#  '346d29d4-82ea-426c-8732-5469e447e0a0',
#  '8e0e4277-82da-4c9b-8e37-41444e2891ea',
#  'c5459ad2-9103-4646-89f4-990c0da021ee',
# ...

# %%
collection.add_documents(chunks2[50:101])
# Out:
# ['a29d8b26-3e9f-4d8c-9fe0-a40d8f0fe984',
#  'c34084a2-84bf-4c9e-8b20-3ce1dfc733a2',
#  '196d9b23-f910-464f-b2a2-2734c20cf5f7',
#  'e794b292-3191-4cc5-aa73-04398f63d6a2',
#  '2a5eca4d-8145-437f-aa98-53358ed24169',
#  '7989b073-35fd-476d-9777-43a4eeb859e0',
#  'd30a6c4b-7403-4650-b5de-47031511de04',
#  '5d259fdf-dcfe-4b81-8730-1735b7be0b72',
#  'f75b5545-cf72-44b4-bf79-f289f905a023',
#  '327592e0-9d34-4ded-8f64-174245d44939',
#  'a110e515-9635-4a28-88e6-50ba4d8eecb3',
#  'cfa18bab-9476-44b4-ad37-c0a0ecf4542f',
#  '909fd3e1-58b7-47cb-a5bc-14f5b717a472',
#  '8c8a77ee-cdbf-458b-892f-74eeba5d64c5',
#  '2e2c777c-75bf-4cb3-a580-46a5354fa612',
#  'a436c376-e428-4b70-8ac4-31d25e36a4ff',
#  '092fc80c-37ff-4b9c-b9a9-927b83281c9e',
#  'b89926e4-fe87-4e05-a0ac-091e4d1961d2',
#  'd1e80dca-0399-40db-baa1-ac5489cd2060',
#  'f996a024-bc8a-4e46-b14f-0f7753fe3868',
#  '7825aa1e-8666-4250-8c3e-f3bd46c6af6c',
#  '4609c888-6734-45ed-8052-45ec13e5dbfd',
#  '636d45d9-7b1c-43cc-a5de-e9d5d1eb8102',
# ...

# %%
collection.get()["metadatas"], len(collection.get()["ids"])
# Out:
# ([{'page': 35,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\alice-in-wonderland.pdf'},
#   {'page': 9,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\Franz_Kafka_The_Metamorphosis.pdf'},
#   {'page': 36,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\alice-in-wonderland.pdf'},
#   {'page': 25,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\alice-in-wonderland.pdf'},
#   {'page': 60,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\alice-in-wonderland.pdf'},
#   {'page': 4,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\Franz_Kafka_The_Metamorphosis.pdf'},
#   {'page': 37,
#    'source': 'C:\\Users\\Usuario\\Desktop\\Universidad_23_24\\TFG\\EL_NUEVO\\alice-in-wonderland.pdf'},
#   {'page': 48,
# ...

# %%
"collection.delete_collection()"
# Out:
# 'collection.delete_collection()'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
